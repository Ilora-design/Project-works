# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Ilora, Erjola_Business Challenge I_Pair Assignment</title>
# </head>
# <body>
#   <h1>A1: Retiree Income Projection Assignment</h1>
#   <p><strong>Name:</strong> Ilora Bandyopadhyay, Erjola Avdiaj</p>
#   <p><strong>Date:</strong> 12/18/2023</p>
#   <p><strong>Course:</strong> Business Challenge I</p>
#   <p><strong>Program:</strong> MBAN (Cohort 2)</p>
#   <p><strong>School:</strong> Hult International Business School Boston</p>
#   </ol>
# </body>
# </html>

# %% [markdown]
# # Introduction
# This user - friendly code can help Retiree family in Massachusetts (MA) or California (CA) to plan for the future.
# The code considers Federal tax and state tax, interest from savings and IRA account and, expenses to forecast how long the savings might last.
# Being straightforward and easy to understand, this code can be easily used by anybody.
# The code has three sections:
# * Section 1: Gives the expenses forecast
# * Section 2: Gives retiree income projection for residents of MA
# * Section 3: Gives retiree income projection for residents of CA
#
# Here is the demo video on how to use the code: https://www.youtube.com/watch?v=wxSrpxelGVA

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")  # This is to ignore any warnings that might pop up during execution

# Load Libraries

import pandas as pd                # data manipulation and wrangling
import numpy as np                 # numerical and scientific computing
import matplotlib.pyplot as plt    # general data visualization
import seaborn as sns              # interface for statistical visualization
import sklearn                     # for machine learning
import statsmodels.api as sm       # for statistic models
import sqlite3                     # SQL data management
import os                          # for reading working directory
from scipy import stats

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder


np.random.seed(42)  # To ensure all the probabilistic things are reproducible

# %% [markdown]
# ## Expenses Forecast
# This section asks the user to enter the current annual expense and the number of years they want to look at. The output obtained is expense of each year, considering the corresponding inflation rate. The inflation rate for each year is taken by this code from the file 'Inflation rate.csv' placed in 'data' folder. The file has forecast till 2058. If required, kindly update the numbers in the following format: Year, Percentage Change.

# %%
#Calculating Expenses over the coming years
import pandas as pd

# Specify the path to the datasets
data_path = "./data/"

# Specify the filenames of the datasets
inflation_rate_filename = "Inflation rate.csv"

# Read the CSV files and create backup copies
inflation_rate_df_data = pd.read_csv(data_path + inflation_rate_filename)

# Create working copies of the dataframes for analysis
inflation_rate_df = inflation_rate_df_data.copy()

# Function to calculate annual expenses for a number of years starting from the entered year
def expenses(inflation_rate_df):
    current_year = int(input("Enter the current year: ")) # takes input from the user
    annual_expenses = float(input("Enter your annual expenses: ")) # takes input from the user
    years = int(input("Enter the number of years: ")) # takes input from the user
    start_year_index = current_year - 2023
    inflation_rates = inflation_rate_df["Percentage Change"].values[start_year_index:start_year_index + years] # Refers to inflation rates from the .csv file

    for year, inflation_rate in enumerate(inflation_rates):
        adjusted_expense = annual_expenses * (1 + inflation_rate) # Calculating annual expense for each year
        print(f"Year {current_year + year}: ${adjusted_expense:.2f}") # Printing out the annual expense for each year
        annual_expenses = adjusted_expense

# Calling the function
expenses(inflation_rate_df)
# Out:
# Enter the current year:  12

# %% [markdown]
# ## Federal tax
# Federal tax has to be paid by everybody living in US. Following is the chart for your reference:
#
# ![image-2.png](attachment:image-2.png)
#
#
# [1] Source: Department of Treasury IRS (Nov 02, 2022). Tax Rate Schedules; Schedule Y-1 If your filling status is Married filling jointly or Qualifying Widow(er), U.S. IRS Federal Tax Rates, page 7; Retrieved on Dec 7th 2023 available at: http://www.irs.gov/pub/irs-pdf/f1040es.pdf

# %% [markdown]
# # Retiree income projection for MA
# This section gives a projection for families living in MA. The user enters the balance in savings account and IRA account and the corresponding annual interest rate and the number of years they want to see the projection for. As on output, this code gives the projection.
#
# ![image-2.png](attachment:image-2.png)
#
# [3] Source: Massachusetts Department of Revenue (Feb 02, 2023). Personal Income Tax for Residents. Retrieved on Dec 7th 2023 available at https://www.mass.gov/info-details/massachusetts-tax-rates

# %%
# Calculating tax for Retiree family in MA
import pandas as pd

# Function to calculate federal tax
def calculate_federal_tax(income):
    # Federal Tax Brackets to calculate the tax
    ## This Part might be updated while there is a change in tax bracket. 
    brackets = [
        (0, 22000, 0.10),
        (22000, 89450, 0.12),
        (89450, 190750, 0.22),
        (190750, 364200, 0.24),
        (364200, 462500, 0.32),
        (462500, 693750, 0.35),
        (693750, float('inf'), 0.37)
    ]

    tax = 0
    income_remaining = income
    
    # For calculating Federal tax based on the brackets
    for lower_limit, upper_limit, rate in brackets:
        taxable_amount = min(upper_limit - lower_limit, income_remaining)
        tax += taxable_amount * rate
        income_remaining -= taxable_amount

        if income_remaining <= 0:
            break  # No more tax to calculate

    return tax

# Function to calculate MA Personal Income tax
def calculate_ma_tax(income):
    ma_tax_rate = 0.05  # Massachusetts Personal Income Tax Rate
    return income * ma_tax_rate

# Function to calculate remaining balance
def calculate_remaining_balance(current_savings, current_ira, savings_interest_rate, ira_interest_rate, annual_expenses, num_years):
    # Constants
    MONTHS_IN_YEAR = 12

    # Monthly interest rates
    monthly_savings_interest = savings_interest_rate / MONTHS_IN_YEAR
    monthly_ira_interest = ira_interest_rate / MONTHS_IN_YEAR

    # Specify the path to the datasets
    data_path = "./data/"

    # Specify the filenames of the datasets
    inflation_rate_filename = "Inflation rate.csv"

    # Read the CSV file for inflation rates
    inflation_rate_df_data = pd.read_csv(data_path + inflation_rate_filename)

    # Create working copies of the dataframes for analysis
    inflation_rate_df = inflation_rate_df_data.copy()

    # Initializing the variables
    remaining_balance = current_savings
    ira_balance = current_ira
    total_federal_tax_paid = 0  # Variable to add cumulatively federal tax over the years
    total_ma_tax_paid = 0  # Variable to add cumulatively MA state tax over the years

    for year in range(2023, 2023 + num_years):
        inflation_rate = inflation_rate_df.loc[year - 2023, 'Percentage Change']  # Fetching inflation rate for the current year
        annual_expense = annual_expenses * (1 + inflation_rate)

        for month in range(1, MONTHS_IN_YEAR + 1):
            # Calculating interest on IRA and Savings
            interest_on_ira = ira_balance * monthly_ira_interest
            interest_on_savings = remaining_balance * monthly_savings_interest

            # Calculating total income(from savings account ONLY)
            income = interest_on_savings

            # Initialize tax variables before conditional statement
            federal_tax = 0
            ma_tax = 0

            # Paying taxes in April starting from April 2024
            if year >= 2024 and month == 4:
                annual_income_for_tax = calculate_annual_income_for_tax(income, month)
                federal_tax = calculate_federal_tax(annual_income_for_tax)
                ma_tax = calculate_ma_tax(annual_income_for_tax)
                total_federal_tax_paid += federal_tax  # Accumulate federal tax
                total_ma_tax_paid += ma_tax  # Accumulate MA state tax

            total_tax = federal_tax + ma_tax

            # Calculating expenses with inflation
            expenses = annual_expense / MONTHS_IN_YEAR

            # Calculating remaining balance after expenses and taxes
            remaining_balance = remaining_balance + income - expenses - total_tax

            # If remaining balance is negative, to use IRA to cover the deficit
            if remaining_balance < 0:
                # Calculate additional federal tax on IRA withdrawal
                additional_tax_on_ira = calculate_federal_tax(ira_balance)
                total_tax += additional_tax_on_ira

                # Adjusting income and remaining balance
                income -= total_tax
                remaining_balance += ira_balance
                ira_balance = 0

            

            # Updating IRA balance with interest
            ira_balance += interest_on_ira

            # Printing results for the current month
            print(f"Year {year}, Month {month}:")
            print(f"Income: {income:.2f}")
            print(f"Expenses: {expenses:.2f}")
            print(f"Remaining Balance: {remaining_balance:.2f}")
            print(f"IRA Balance: {ira_balance:.2f}")
            print(f"Federal Tax: {federal_tax:.2f}")
            print(f"MA Tax: {ma_tax:.2f}")
            print(f"Total Tax: {total_tax:.2f}\n")

        # Updating annual_expenses for the next year
        annual_expenses *= (1 + inflation_rate)

    print("Projection complete.")

    # Output the total federal tax and MA state tax paid in the first 10 years
    print(f"Total Federal Tax Paid in the First 10 Years: {total_federal_tax_paid:.2f}")
    print(f"Total MA State Tax Paid in the First 10 Years: {total_ma_tax_paid:.2f}")

def calculate_annual_income_for_tax(savings_interest, month):
    # To calculate the annual income for tax based on the tax calculation period
    return savings_interest * 12 if month == 4 else savings_interest

# Getting user input
current_savings = float(input("Enter current savings balance: "))
current_ira = float(input("Enter current IRA balance: "))
savings_interest_rate = float(input("Enter annual interest rate for savings account (in %): ")) / 100
ira_interest_rate = float(input("Enter annual interest rate for IRA account (in %): ")) / 100
annual_expenses = float(input("Enter annual expenses: "))
num_years = int(input("Enter the number of years for projections: "))

# Calling the function to calculate and display projections
calculate_remaining_balance(current_savings, current_ira, savings_interest_rate, ira_interest_rate, annual_expenses, num_years)
# Out:
# Enter current savings balance: 1000
# Enter current IRA balance: 2000
# Enter annual interest rate for savings account (in %): 6
# Enter annual interest rate for IRA account (in %): 8
# Enter annual expenses: 500
# Enter the number of years for projections: 20
# Year 2023, Month 1:
# Income: 5.00
# Expenses: 45.04
# Remaining Balance: 959.96
# IRA Balance: 2013.33
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 2:
# Income: 4.80
# Expenses: 45.04
# Remaining Balance: 919.72
# IRA Balance: 2026.76
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 3:
# Income: 4.60
# Expenses: 45.04
# Remaining Balance: 879.28
# IRA Balance: 2040.27
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 4:
# Income: 4.40
# Expenses: 45.04
# Remaining Balance: 838.64
# IRA Balance: 2053.87
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 5:
# Income: 4.19
# Expenses: 45.04
# Remaining Balance: 797.79
# IRA Balance: 2067.56
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 6:
# Income: 3.99
# Expenses: 45.04
# Remaining Balance: 756.74
# IRA Balance: 2081.35
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 7:
# Income: 3.78
# Expenses: 45.04
# Remaining Balance: 715.48
# IRA Balance: 2095.22
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 8:
# Income: 3.58
# Expenses: 45.04
# Remaining Balance: 674.02
# IRA Balance: 2109.19
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 9:
# Income: 3.37
# Expenses: 45.04
# Remaining Balance: 632.35
# IRA Balance: 2123.25
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 10:
# Income: 3.16
# Expenses: 45.04
# Remaining Balance: 590.47
# IRA Balance: 2137.41
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 11:
# Income: 2.95
# Expenses: 45.04
# Remaining Balance: 548.39
# IRA Balance: 2151.65
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 12:
# Income: 2.74
# Expenses: 45.04
# Remaining Balance: 506.09
# IRA Balance: 2166.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 1:
# Income: 2.53
# Expenses: 47.20
# Remaining Balance: 461.42
# IRA Balance: 2180.44
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 2:
# Income: 2.31
# Expenses: 47.20
# Remaining Balance: 416.53
# IRA Balance: 2194.98
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 3:
# Income: 2.08
# Expenses: 47.20
# Remaining Balance: 371.42
# IRA Balance: 2209.61
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 4:
# Income: 1.86
# Expenses: 47.20
# Remaining Balance: 322.74
# IRA Balance: 2224.34
# Federal Tax: 2.23
# MA Tax: 1.11
# Total Tax: 3.34
#
# Year 2024, Month 5:
# Income: 1.61
# Expenses: 47.20
# Remaining Balance: 277.15
# IRA Balance: 2239.17
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 6:
# Income: 1.39
# Expenses: 47.20
# Remaining Balance: 231.34
# IRA Balance: 2254.10
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 7:
# Income: 1.16
# Expenses: 47.20
# Remaining Balance: 185.30
# IRA Balance: 2269.12
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 8:
# Income: 0.93
# Expenses: 47.20
# Remaining Balance: 139.03
# IRA Balance: 2284.25
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 9:
# Income: 0.70
# Expenses: 47.20
# Remaining Balance: 92.53
# IRA Balance: 2299.48
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 10:
# Income: 0.46
# Expenses: 47.20
# Remaining Balance: 45.79
# IRA Balance: 2314.81
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 11:
# Income: -231.25
# Expenses: 47.20
# Remaining Balance: 2313.64
# IRA Balance: 15.43
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 231.48
#
# Year 2024, Month 12:
# Income: 11.57
# Expenses: 47.20
# Remaining Balance: 2278.01
# IRA Balance: 15.53
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 1:
# Income: 11.39
# Expenses: 48.62
# Remaining Balance: 2240.78
# IRA Balance: 15.64
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 2:
# Income: 11.20
# Expenses: 48.62
# Remaining Balance: 2203.36
# IRA Balance: 15.74
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 3:
# Income: 11.02
# Expenses: 48.62
# Remaining Balance: 2165.76
# IRA Balance: 15.85
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 4:
# Income: 10.83
# Expenses: 48.62
# Remaining Balance: 2108.48
# IRA Balance: 15.95
# Federal Tax: 12.99
# MA Tax: 6.50
# Total Tax: 19.49
#
# Year 2025, Month 5:
# Income: 10.54
# Expenses: 48.62
# Remaining Balance: 2070.40
# IRA Balance: 16.06
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 6:
# Income: 10.35
# Expenses: 48.62
# Remaining Balance: 2032.13
# IRA Balance: 16.17
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 7:
# Income: 10.16
# Expenses: 48.62
# Remaining Balance: 1993.68
# IRA Balance: 16.27
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 8:
# Income: 9.97
# Expenses: 48.62
# Remaining Balance: 1955.03
# IRA Balance: 16.38
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 9:
# Income: 9.78
# Expenses: 48.62
# Remaining Balance: 1916.18
# IRA Balance: 16.49
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 10:
# Income: 9.58
# Expenses: 48.62
# Remaining Balance: 1877.14
# IRA Balance: 16.60
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 11:
# Income: 9.39
# Expenses: 48.62
# Remaining Balance: 1837.91
# IRA Balance: 16.71
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 12:
# Income: 9.19
# Expenses: 48.62
# Remaining Balance: 1798.48
# IRA Balance: 16.82
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 1:
# Income: 8.99
# Expenses: 49.68
# Remaining Balance: 1757.80
# IRA Balance: 16.94
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 2:
# Income: 8.79
# Expenses: 49.68
# Remaining Balance: 1716.91
# IRA Balance: 17.05
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 3:
# Income: 8.58
# Expenses: 49.68
# Remaining Balance: 1675.81
# IRA Balance: 17.16
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 4:
# Income: 8.38
# Expenses: 49.68
# Remaining Balance: 1619.43
# IRA Balance: 17.28
# Federal Tax: 10.05
# MA Tax: 5.03
# Total Tax: 15.08
#
# Year 2026, Month 5:
# Income: 8.10
# Expenses: 49.68
# Remaining Balance: 1577.85
# IRA Balance: 17.39
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 6:
# Income: 7.89
# Expenses: 49.68
# Remaining Balance: 1536.06
# IRA Balance: 17.51
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 7:
# Income: 7.68
# Expenses: 49.68
# Remaining Balance: 1494.07
# IRA Balance: 17.63
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 8:
# Income: 7.47
# Expenses: 49.68
# Remaining Balance: 1451.86
# IRA Balance: 17.74
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 9:
# Income: 7.26
# Expenses: 49.68
# Remaining Balance: 1409.44
# IRA Balance: 17.86
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 10:
# Income: 7.05
# Expenses: 49.68
# Remaining Balance: 1366.81
# IRA Balance: 17.98
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 11:
# Income: 6.83
# Expenses: 49.68
# Remaining Balance: 1323.97
# IRA Balance: 18.10
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 12:
# Income: 6.62
# Expenses: 49.68
# Remaining Balance: 1280.91
# IRA Balance: 18.22
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 1:
# Income: 6.40
# Expenses: 50.70
# Remaining Balance: 1236.62
# IRA Balance: 18.34
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 2:
# Income: 6.18
# Expenses: 50.70
# Remaining Balance: 1192.10
# IRA Balance: 18.46
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 3:
# Income: 5.96
# Expenses: 50.70
# Remaining Balance: 1147.37
# IRA Balance: 18.59
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 4:
# Income: 5.74
# Expenses: 50.70
# Remaining Balance: 1092.08
# IRA Balance: 18.71
# Federal Tax: 6.88
# MA Tax: 3.44
# Total Tax: 10.33
#
# Year 2027, Month 5:
# Income: 5.46
# Expenses: 50.70
# Remaining Balance: 1046.84
# IRA Balance: 18.84
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 6:
# Income: 5.23
# Expenses: 50.70
# Remaining Balance: 1001.38
# IRA Balance: 18.96
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 7:
# Income: 5.01
# Expenses: 50.70
# Remaining Balance: 955.69
# IRA Balance: 19.09
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 8:
# Income: 4.78
# Expenses: 50.70
# Remaining Balance: 909.77
# IRA Balance: 19.22
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 9:
# Income: 4.55
# Expenses: 50.70
# Remaining Balance: 863.62
# IRA Balance: 19.34
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 10:
# Income: 4.32
# Expenses: 50.70
# Remaining Balance: 817.24
# IRA Balance: 19.47
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 11:
# Income: 4.09
# Expenses: 50.70
# Remaining Balance: 770.63
# IRA Balance: 19.60
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 12:
# Income: 3.85
# Expenses: 50.70
# Remaining Balance: 723.79
# IRA Balance: 19.73
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 1:
# Income: 3.62
# Expenses: 51.74
# Remaining Balance: 675.66
# IRA Balance: 19.86
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 2:
# Income: 3.38
# Expenses: 51.74
# Remaining Balance: 627.30
# IRA Balance: 20.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 3:
# Income: 3.14
# Expenses: 51.74
# Remaining Balance: 578.69
# IRA Balance: 20.13
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 4:
# Income: 2.89
# Expenses: 51.74
# Remaining Balance: 524.64
# IRA Balance: 20.26
# Federal Tax: 3.47
# MA Tax: 1.74
# Total Tax: 5.21
#
# Year 2028, Month 5:
# Income: 2.62
# Expenses: 51.74
# Remaining Balance: 475.52
# IRA Balance: 20.40
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 6:
# Income: 2.38
# Expenses: 51.74
# Remaining Balance: 426.15
# IRA Balance: 20.54
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 7:
# Income: 2.13
# Expenses: 51.74
# Remaining Balance: 376.54
# IRA Balance: 20.67
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 8:
# Income: 1.88
# Expenses: 51.74
# Remaining Balance: 326.68
# IRA Balance: 20.81
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 9:
# Income: 1.63
# Expenses: 51.74
# Remaining Balance: 276.57
# IRA Balance: 20.95
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 10:
# Income: 1.38
# Expenses: 51.74
# Remaining Balance: 226.21
# IRA Balance: 21.09
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 11:
# Income: 1.13
# Expenses: 51.74
# Remaining Balance: 175.60
# IRA Balance: 21.23
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2028, Month 12:
# Income: 0.88
# Expenses: 51.74
# Remaining Balance: 124.73
# IRA Balance: 21.37
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 1:
# Income: 0.62
# Expenses: 52.87
# Remaining Balance: 72.48
# IRA Balance: 21.51
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 2:
# Income: 0.36
# Expenses: 52.87
# Remaining Balance: 19.97
# IRA Balance: 21.66
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 3:
# Income: -2.07
# Expenses: 52.87
# Remaining Balance: -11.14
# IRA Balance: 0.14
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 2.17
#
# Year 2029, Month 4:
# Income: 0.03
# Expenses: 52.87
# Remaining Balance: -63.83
# IRA Balance: 0.00
# Federal Tax: -0.07
# MA Tax: -0.03
# Total Tax: -0.09
#
# Year 2029, Month 5:
# Income: -0.32
# Expenses: 52.87
# Remaining Balance: -117.02
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 6:
# Income: -0.59
# Expenses: 52.87
# Remaining Balance: -170.48
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 7:
# Income: -0.85
# Expenses: 52.87
# Remaining Balance: -224.20
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 8:
# Income: -1.12
# Expenses: 52.87
# Remaining Balance: -278.20
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 9:
# Income: -1.39
# Expenses: 52.87
# Remaining Balance: -332.46
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 10:
# Income: -1.66
# Expenses: 52.87
# Remaining Balance: -387.00
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 11:
# Income: -1.93
# Expenses: 52.87
# Remaining Balance: -441.81
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2029, Month 12:
# Income: -2.21
# Expenses: 52.87
# Remaining Balance: -496.89
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 1:
# Income: -2.48
# Expenses: 54.07
# Remaining Balance: -553.44
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 2:
# Income: -2.77
# Expenses: 54.07
# Remaining Balance: -610.27
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 3:
# Income: -3.05
# Expenses: 54.07
# Remaining Balance: -667.39
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 4:
# Income: 2.67
# Expenses: 54.07
# Remaining Balance: -718.78
# IRA Balance: 0.00
# Federal Tax: -4.00
# MA Tax: -2.00
# Total Tax: -6.01
#
# Year 2030, Month 5:
# Income: -3.59
# Expenses: 54.07
# Remaining Balance: -776.44
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 6:
# Income: -3.88
# Expenses: 54.07
# Remaining Balance: -834.39
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 7:
# Income: -4.17
# Expenses: 54.07
# Remaining Balance: -892.62
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 8:
# Income: -4.46
# Expenses: 54.07
# Remaining Balance: -951.15
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 9:
# Income: -4.76
# Expenses: 54.07
# Remaining Balance: -1009.97
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 10:
# Income: -5.05
# Expenses: 54.07
# Remaining Balance: -1069.09
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 11:
# Income: -5.35
# Expenses: 54.07
# Remaining Balance: -1128.50
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2030, Month 12:
# Income: -5.64
# Expenses: 54.07
# Remaining Balance: -1188.21
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 1:
# Income: -5.94
# Expenses: 55.29
# Remaining Balance: -1249.44
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 2:
# Income: -6.25
# Expenses: 55.29
# Remaining Balance: -1310.98
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 3:
# Income: -6.55
# Expenses: 55.29
# Remaining Balance: -1372.83
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 4:
# Income: 5.49
# Expenses: 55.29
# Remaining Balance: -1422.63
# IRA Balance: 0.00
# Federal Tax: -8.24
# MA Tax: -4.12
# Total Tax: -12.36
#
# Year 2031, Month 5:
# Income: -7.11
# Expenses: 55.29
# Remaining Balance: -1485.03
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 6:
# Income: -7.43
# Expenses: 55.29
# Remaining Balance: -1547.75
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 7:
# Income: -7.74
# Expenses: 55.29
# Remaining Balance: -1610.78
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 8:
# Income: -8.05
# Expenses: 55.29
# Remaining Balance: -1674.12
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 9:
# Income: -8.37
# Expenses: 55.29
# Remaining Balance: -1737.79
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 10:
# Income: -8.69
# Expenses: 55.29
# Remaining Balance: -1801.77
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 11:
# Income: -9.01
# Expenses: 55.29
# Remaining Balance: -1866.07
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2031, Month 12:
# Income: -9.33
# Expenses: 55.29
# Remaining Balance: -1930.69
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 1:
# Income: -9.65
# Expenses: 56.55
# Remaining Balance: -1996.89
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 2:
# Income: -9.98
# Expenses: 56.55
# Remaining Balance: -2063.42
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 3:
# Income: -10.32
# Expenses: 56.55
# Remaining Balance: -2130.29
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 4:
# Income: 8.52
# Expenses: 56.55
# Remaining Balance: -2178.32
# IRA Balance: 0.00
# Federal Tax: -12.78
# MA Tax: -6.39
# Total Tax: -19.17
#
# Year 2032, Month 5:
# Income: -10.89
# Expenses: 56.55
# Remaining Balance: -2245.76
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 6:
# Income: -11.23
# Expenses: 56.55
# Remaining Balance: -2313.54
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 7:
# Income: -11.57
# Expenses: 56.55
# Remaining Balance: -2381.65
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 8:
# Income: -11.91
# Expenses: 56.55
# Remaining Balance: -2450.11
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 9:
# Income: -12.25
# Expenses: 56.55
# Remaining Balance: -2518.91
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 10:
# Income: -12.59
# Expenses: 56.55
# Remaining Balance: -2588.05
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 11:
# Income: -12.94
# Expenses: 56.55
# Remaining Balance: -2657.54
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2032, Month 12:
# Income: -13.29
# Expenses: 56.55
# Remaining Balance: -2727.38
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 1:
# Income: -13.64
# Expenses: 57.84
# Remaining Balance: -2798.85
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 2:
# Income: -13.99
# Expenses: 57.84
# Remaining Balance: -2870.68
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 3:
# Income: -14.35
# Expenses: 57.84
# Remaining Balance: -2942.87
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 4:
# Income: 11.77
# Expenses: 57.84
# Remaining Balance: -2988.93
# IRA Balance: 0.00
# Federal Tax: -17.66
# MA Tax: -8.83
# Total Tax: -26.49
#
# Year 2033, Month 5:
# Income: -14.94
# Expenses: 57.84
# Remaining Balance: -3061.71
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 6:
# Income: -15.31
# Expenses: 57.84
# Remaining Balance: -3134.86
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 7:
# Income: -15.67
# Expenses: 57.84
# Remaining Balance: -3208.37
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 8:
# Income: -16.04
# Expenses: 57.84
# Remaining Balance: -3282.25
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 9:
# Income: -16.41
# Expenses: 57.84
# Remaining Balance: -3356.50
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 10:
# Income: -16.78
# Expenses: 57.84
# Remaining Balance: -3431.11
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 11:
# Income: -17.16
# Expenses: 57.84
# Remaining Balance: -3506.11
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2033, Month 12:
# Income: -17.53
# Expenses: 57.84
# Remaining Balance: -3581.47
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 1:
# Income: -17.91
# Expenses: 59.16
# Remaining Balance: -3658.54
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 2:
# Income: -18.29
# Expenses: 59.16
# Remaining Balance: -3735.99
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 3:
# Income: -18.68
# Expenses: 59.16
# Remaining Balance: -3813.82
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 4:
# Income: 15.26
# Expenses: 59.16
# Remaining Balance: -3857.72
# IRA Balance: 0.00
# Federal Tax: -22.88
# MA Tax: -11.44
# Total Tax: -34.32
#
# Year 2034, Month 5:
# Income: -19.29
# Expenses: 59.16
# Remaining Balance: -3936.17
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 6:
# Income: -19.68
# Expenses: 59.16
# Remaining Balance: -4015.01
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 7:
# Income: -20.08
# Expenses: 59.16
# Remaining Balance: -4094.24
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 8:
# Income: -20.47
# Expenses: 59.16
# Remaining Balance: -4173.87
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 9:
# Income: -20.87
# Expenses: 59.16
# Remaining Balance: -4253.89
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 10:
# Income: -21.27
# Expenses: 59.16
# Remaining Balance: -4334.32
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 11:
# Income: -21.67
# Expenses: 59.16
# Remaining Balance: -4415.15
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2034, Month 12:
# Income: -22.08
# Expenses: 59.16
# Remaining Balance: -4496.38
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 1:
# Income: -22.48
# Expenses: 60.52
# Remaining Balance: -4579.38
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 2:
# Income: -22.90
# Expenses: 60.52
# Remaining Balance: -4662.79
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 3:
# Income: -23.31
# Expenses: 60.52
# Remaining Balance: -4746.62
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 4:
# Income: 18.99
# Expenses: 60.52
# Remaining Balance: -4788.15
# IRA Balance: 0.00
# Federal Tax: -28.48
# MA Tax: -14.24
# Total Tax: -42.72
#
# Year 2035, Month 5:
# Income: -23.94
# Expenses: 60.52
# Remaining Balance: -4872.61
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 6:
# Income: -24.36
# Expenses: 60.52
# Remaining Balance: -4957.49
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 7:
# Income: -24.79
# Expenses: 60.52
# Remaining Balance: -5042.80
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 8:
# Income: -25.21
# Expenses: 60.52
# Remaining Balance: -5128.53
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 9:
# Income: -25.64
# Expenses: 60.52
# Remaining Balance: -5214.69
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 10:
# Income: -26.07
# Expenses: 60.52
# Remaining Balance: -5301.28
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 11:
# Income: -26.51
# Expenses: 60.52
# Remaining Balance: -5388.30
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2035, Month 12:
# Income: -26.94
# Expenses: 60.52
# Remaining Balance: -5475.76
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 1:
# Income: -27.38
# Expenses: 61.91
# Remaining Balance: -5565.05
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 2:
# Income: -27.83
# Expenses: 61.91
# Remaining Balance: -5654.78
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 3:
# Income: -28.27
# Expenses: 61.91
# Remaining Balance: -5744.96
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 4:
# Income: 22.98
# Expenses: 61.91
# Remaining Balance: -5783.89
# IRA Balance: 0.00
# Federal Tax: -34.47
# MA Tax: -17.23
# Total Tax: -51.70
#
# Year 2036, Month 5:
# Income: -28.92
# Expenses: 61.91
# Remaining Balance: -5874.72
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 6:
# Income: -29.37
# Expenses: 61.91
# Remaining Balance: -5966.01
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 7:
# Income: -29.83
# Expenses: 61.91
# Remaining Balance: -6057.74
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 8:
# Income: -30.29
# Expenses: 61.91
# Remaining Balance: -6149.94
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 9:
# Income: -30.75
# Expenses: 61.91
# Remaining Balance: -6242.60
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 10:
# Income: -31.21
# Expenses: 61.91
# Remaining Balance: -6335.72
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 11:
# Income: -31.68
# Expenses: 61.91
# Remaining Balance: -6429.31
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2036, Month 12:
# Income: -32.15
# Expenses: 61.91
# Remaining Balance: -6523.37
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 1:
# Income: -32.62
# Expenses: 63.33
# Remaining Balance: -6619.32
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 2:
# Income: -33.10
# Expenses: 63.33
# Remaining Balance: -6715.75
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 3:
# Income: -33.58
# Expenses: 63.33
# Remaining Balance: -6812.66
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 4:
# Income: 27.25
# Expenses: 63.33
# Remaining Balance: -6848.74
# IRA Balance: 0.00
# Federal Tax: -40.88
# MA Tax: -20.44
# Total Tax: -61.31
#
# Year 2037, Month 5:
# Income: -34.24
# Expenses: 63.33
# Remaining Balance: -6946.32
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 6:
# Income: -34.73
# Expenses: 63.33
# Remaining Balance: -7044.38
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 7:
# Income: -35.22
# Expenses: 63.33
# Remaining Balance: -7142.94
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 8:
# Income: -35.71
# Expenses: 63.33
# Remaining Balance: -7241.98
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 9:
# Income: -36.21
# Expenses: 63.33
# Remaining Balance: -7341.53
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 10:
# Income: -36.71
# Expenses: 63.33
# Remaining Balance: -7441.57
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 11:
# Income: -37.21
# Expenses: 63.33
# Remaining Balance: -7542.11
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2037, Month 12:
# Income: -37.71
# Expenses: 63.33
# Remaining Balance: -7643.15
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 1:
# Income: -38.22
# Expenses: 64.79
# Remaining Balance: -7746.16
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 2:
# Income: -38.73
# Expenses: 64.79
# Remaining Balance: -7849.68
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 3:
# Income: -39.25
# Expenses: 64.79
# Remaining Balance: -7953.72
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 4:
# Income: 31.81
# Expenses: 64.79
# Remaining Balance: -7986.69
# IRA Balance: 0.00
# Federal Tax: -47.72
# MA Tax: -23.86
# Total Tax: -71.58
#
# Year 2038, Month 5:
# Income: -39.93
# Expenses: 64.79
# Remaining Balance: -8091.41
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 6:
# Income: -40.46
# Expenses: 64.79
# Remaining Balance: -8196.66
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 7:
# Income: -40.98
# Expenses: 64.79
# Remaining Balance: -8302.43
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 8:
# Income: -41.51
# Expenses: 64.79
# Remaining Balance: -8408.73
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 9:
# Income: -42.04
# Expenses: 64.79
# Remaining Balance: -8515.57
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 10:
# Income: -42.58
# Expenses: 64.79
# Remaining Balance: -8622.94
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 11:
# Income: -43.11
# Expenses: 64.79
# Remaining Balance: -8730.84
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2038, Month 12:
# Income: -43.65
# Expenses: 64.79
# Remaining Balance: -8839.28
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 1:
# Income: -44.20
# Expenses: 66.28
# Remaining Balance: -8949.76
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 2:
# Income: -44.75
# Expenses: 66.28
# Remaining Balance: -9060.79
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 3:
# Income: -45.30
# Expenses: 66.28
# Remaining Balance: -9172.37
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 4:
# Income: 36.69
# Expenses: 66.28
# Remaining Balance: -9201.96
# IRA Balance: 0.00
# Federal Tax: -55.03
# MA Tax: -27.52
# Total Tax: -82.55
#
# Year 2039, Month 5:
# Income: -46.01
# Expenses: 66.28
# Remaining Balance: -9314.25
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 6:
# Income: -46.57
# Expenses: 66.28
# Remaining Balance: -9427.10
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 7:
# Income: -47.14
# Expenses: 66.28
# Remaining Balance: -9540.52
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 8:
# Income: -47.70
# Expenses: 66.28
# Remaining Balance: -9654.50
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 9:
# Income: -48.27
# Expenses: 66.28
# Remaining Balance: -9769.05
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 10:
# Income: -48.85
# Expenses: 66.28
# Remaining Balance: -9884.18
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 11:
# Income: -49.42
# Expenses: 66.28
# Remaining Balance: -9999.88
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2039, Month 12:
# Income: -50.00
# Expenses: 66.28
# Remaining Balance: -10116.16
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 1:
# Income: -50.58
# Expenses: 67.80
# Remaining Balance: -10234.54
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 2:
# Income: -51.17
# Expenses: 67.80
# Remaining Balance: -10353.52
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 3:
# Income: -51.77
# Expenses: 67.80
# Remaining Balance: -10473.09
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 4:
# Income: 41.89
# Expenses: 67.80
# Remaining Balance: -10499.00
# IRA Balance: 0.00
# Federal Tax: -62.84
# MA Tax: -31.42
# Total Tax: -94.26
#
# Year 2040, Month 5:
# Income: -52.50
# Expenses: 67.80
# Remaining Balance: -10619.30
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 6:
# Income: -53.10
# Expenses: 67.80
# Remaining Balance: -10740.20
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 7:
# Income: -53.70
# Expenses: 67.80
# Remaining Balance: -10861.71
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 8:
# Income: -54.31
# Expenses: 67.80
# Remaining Balance: -10983.82
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 9:
# Income: -54.92
# Expenses: 67.80
# Remaining Balance: -11106.55
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 10:
# Income: -55.53
# Expenses: 67.80
# Remaining Balance: -11229.88
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 11:
# Income: -56.15
# Expenses: 67.80
# Remaining Balance: -11353.84
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2040, Month 12:
# Income: -56.77
# Expenses: 67.80
# Remaining Balance: -11478.41
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 1:
# Income: -57.39
# Expenses: 69.36
# Remaining Balance: -11605.17
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 2:
# Income: -58.03
# Expenses: 69.36
# Remaining Balance: -11732.56
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 3:
# Income: -58.66
# Expenses: 69.36
# Remaining Balance: -11860.58
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 4:
# Income: 47.44
# Expenses: 69.36
# Remaining Balance: -11882.50
# IRA Balance: 0.00
# Federal Tax: -71.16
# MA Tax: -35.58
# Total Tax: -106.75
#
# Year 2041, Month 5:
# Income: -59.41
# Expenses: 69.36
# Remaining Balance: -12011.28
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 6:
# Income: -60.06
# Expenses: 69.36
# Remaining Balance: -12140.70
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 7:
# Income: -60.70
# Expenses: 69.36
# Remaining Balance: -12270.77
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 8:
# Income: -61.35
# Expenses: 69.36
# Remaining Balance: -12401.48
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 9:
# Income: -62.01
# Expenses: 69.36
# Remaining Balance: -12532.86
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 10:
# Income: -62.66
# Expenses: 69.36
# Remaining Balance: -12664.88
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 11:
# Income: -63.32
# Expenses: 69.36
# Remaining Balance: -12797.57
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2041, Month 12:
# Income: -63.99
# Expenses: 69.36
# Remaining Balance: -12930.92
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 1:
# Income: -64.65
# Expenses: 70.96
# Remaining Balance: -13066.54
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 2:
# Income: -65.33
# Expenses: 70.96
# Remaining Balance: -13202.83
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 3:
# Income: -66.01
# Expenses: 70.96
# Remaining Balance: -13339.80
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 4:
# Income: 53.36
# Expenses: 70.96
# Remaining Balance: -13357.40
# IRA Balance: 0.00
# Federal Tax: -80.04
# MA Tax: -40.02
# Total Tax: -120.06
#
# Year 2042, Month 5:
# Income: -66.79
# Expenses: 70.96
# Remaining Balance: -13495.15
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 6:
# Income: -67.48
# Expenses: 70.96
# Remaining Balance: -13633.58
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 7:
# Income: -68.17
# Expenses: 70.96
# Remaining Balance: -13772.71
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 8:
# Income: -68.86
# Expenses: 70.96
# Remaining Balance: -13912.53
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 9:
# Income: -69.56
# Expenses: 70.96
# Remaining Balance: -14053.05
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 10:
# Income: -70.27
# Expenses: 70.96
# Remaining Balance: -14194.28
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 11:
# Income: -70.97
# Expenses: 70.96
# Remaining Balance: -14336.21
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Year 2042, Month 12:
# Income: -71.68
# Expenses: 70.96
# Remaining Balance: -14478.85
# IRA Balance: 0.00
# Federal Tax: 0.00
# MA Tax: 0.00
# Total Tax: 0.00
#
# Projection complete.
# Total Federal Tax Paid in the First 10 Years: -450.62
# Total MA State Tax Paid in the First 10 Years: -225.31

# %% [markdown]
# # Retiree income projection for CA
# This section gives a projection for families living in CA. The user enters the balance in savings account and IRA account and the corresponding annual interest rate and the number of years they want to see the projection for. As on output, this code gives the projection.
# ![image.png](attachment:image.png)
#
# [2] Source: State of California Franchise Tax Board (2022). CALIFORNIA WITHHOLDING SCHEDULES FOR 2023. 2023 Withholding Schedules - Method B (INTERNET) Page 7. Retrieved on Dec 12th 2023.  Available at https://edd.ca.gov/siteassets/files/pdf_pub_ctr/23methb.pdf

# %%
# Calculating tax for retiree family in CA
import pandas as pd

# Function to calculate federal tax
def calculate_federal_tax(income):
    # Federal Tax Brackets
    brackets = [
        (0, 22000, 0.10),
        (22000, 89450, 0.12),
        (89450, 190750, 0.22),
        (190750, 364200, 0.24),
        (364200, 462500, 0.32),
        (462500, 693750, 0.35),
        (693750, float('inf'), 0.37)
    ]

    tax = 0
    income_remaining = income

    for lower_limit, upper_limit, rate in brackets:
        taxable_amount = min(upper_limit - lower_limit, income_remaining)
        tax += taxable_amount * rate
        income_remaining -= taxable_amount

        if income_remaining <= 0:
            break  # No more tax to calculate

    return tax

# Function to calculate CA state tax
def calculate_ca_tax(income):
    # California State Tax Brackets
    brackets = [
        (0, 20198, 0.011),
        (20198, 47884, 0.022),
        (47884, 75576, 0.044),
        (75576, 104910, 0.066),
        (104910, 132590, 0.088),
        (132590, 677278, 0.1023),
        (677278, 812728, 0.1133),
        (812728, 1000000, 0.1243),
        (1000000, 1354550, 0.1353),
        (1354550, float('inf'), 0.1463)
    ]

    tax = 0
    income_remaining = income

    for lower_limit, upper_limit, rate in brackets:
        taxable_amount = min(upper_limit - lower_limit, income_remaining)
        tax += taxable_amount * rate
        income_remaining -= taxable_amount

        if income_remaining <= 0:
            break  # No more tax to calculate

    return tax

# Function to calculate remaining balance
def calculate_remaining_balance(current_savings, current_ira, savings_interest_rate, ira_interest_rate, annual_expenses, num_years):
    # Constants
    MONTHS_IN_YEAR = 12

    # Monthly interest rates
    monthly_savings_interest = savings_interest_rate / MONTHS_IN_YEAR
    monthly_ira_interest = ira_interest_rate / MONTHS_IN_YEAR

    # Specify the path to the datasets
    data_path = "./data/"

    # Specify the filenames of the datasets
    inflation_rate_filename = "Inflation rate.csv"

    # Read the CSV file for inflation rates
    inflation_rate_df_data = pd.read_csv(data_path + inflation_rate_filename)

    # Create working copies of the dataframes for analysis
    inflation_rate_df = inflation_rate_df_data.copy()

    # Initializing variables
    remaining_balance = current_savings
    ira_balance = current_ira
    total_federal_tax_paid = 0  # Variable to add cumulative federal tax over the years
    total_ca_tax_paid = 0  # Variable to add cumulative CA state tax over the years

    for year in range(2023, 2023 + num_years):
        inflation_rate = inflation_rate_df.loc[year - 2023, 'Percentage Change']  # Fetching inflation rate for the current year
        annual_expense = annual_expenses * (1 + inflation_rate)

        for month in range(1, MONTHS_IN_YEAR + 1):
            # Calculating interest on IRA and Savings
            interest_on_ira = ira_balance * monthly_ira_interest
            interest_on_savings = remaining_balance * monthly_savings_interest

            # Calculating total income (only from savings account)
            income = interest_on_savings

            # Initializing tax variables before conditional statement
            federal_tax = 0
            ca_tax = 0

            # Paying taxes in April starting from April 2024
            if year >= 2024 and month == 4:
                annual_income_for_tax = calculate_annual_income_for_tax(income, month)
                federal_tax = calculate_federal_tax(annual_income_for_tax)
                ca_tax = calculate_ca_tax(annual_income_for_tax)
                total_federal_tax_paid += federal_tax  # Accumulate federal tax
                total_ca_tax_paid += ca_tax  # Accumulate CA state tax

            total_tax = federal_tax + ca_tax

            # Calculating expenses with inflation
            expenses = annual_expense / MONTHS_IN_YEAR

            # Calculating remaining balance after expenses and taxes
            remaining_balance = remaining_balance + income - expenses - total_tax

            # If remaining balance is negative, use IRA to cover the deficit
            if remaining_balance < 0:
                # Calculate additional federal tax on IRA withdrawal
                additional_tax_on_ira = calculate_federal_tax(ira_balance)
                total_tax += additional_tax_on_ira

                # Adjusting income and remaining balance
                income -= total_tax
                remaining_balance += ira_balance
                ira_balance = 0

            

            # Updating IRA balance with interest
            ira_balance += interest_on_ira

            # Printing results for the current month
            print(f"Year {year}, Month {month}:")
            print(f"Income: {income:.2f}")
            print(f"Expenses: {expenses:.2f}")
            print(f"Remaining Balance: {remaining_balance:.2f}")
            print(f"IRA Balance: {ira_balance:.2f}")
            print(f"Federal Tax: {federal_tax:.2f}")
            print(f"CA Tax: {ca_tax:.2f}")
            print(f"Total Tax: {total_tax:.2f}\n")

        # Updating annual_expenses for the next year
        annual_expenses *= (1 + inflation_rate)

    print("Projection complete.")

    # Output the total federal tax and CA state tax paid in the first 10 years
    print(f"Total Federal Tax Paid in the First 10 Years: {total_federal_tax_paid:.2f}")
    print(f"Total CA State Tax Paid in the First 10 Years: {total_ca_tax_paid:.2f}")

def calculate_annual_income_for_tax(savings_interest, month):
    # Calculate the annual income for tax based on the tax calculation period
    return savings_interest * 12 if month == 4 else savings_interest

# Getting user input
current_savings = float(input("Enter current savings balance: "))
current_ira = float(input("Enter current IRA balance: "))
savings_interest_rate = float(input("Enter annual interest rate for savings account (in %): ")) / 100
ira_interest_rate = float(input("Enter annual interest rate for IRA account (in %): ")) / 100
annual_expenses = float(input("Enter annual expenses: "))
num_years = int(input("Enter the number of years for projections: "))

# Calling the function to calculate and display projections
calculate_remaining_balance(current_savings, current_ira, savings_interest_rate, ira_interest_rate, annual_expenses, num_years)
# Out:
# Enter current savings balance: 580000
# Enter current IRA balance: 400000
# Enter annual interest rate for savings account (in %): 6
# Enter annual interest rate for IRA account (in %): 8
# Enter annual expenses: 81500
# Enter the number of years for projections: 5
# Year 2023, Month 1:
# Income: 2900.00
# Expenses: 7341.45
# Remaining Balance: 575558.55
# IRA Balance: 402666.67
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 2:
# Income: 2877.79
# Expenses: 7341.45
# Remaining Balance: 571094.89
# IRA Balance: 405351.11
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 3:
# Income: 2855.47
# Expenses: 7341.45
# Remaining Balance: 566608.91
# IRA Balance: 408053.45
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 4:
# Income: 2833.04
# Expenses: 7341.45
# Remaining Balance: 562100.50
# IRA Balance: 410773.81
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 5:
# Income: 2810.50
# Expenses: 7341.45
# Remaining Balance: 557569.55
# IRA Balance: 413512.30
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 6:
# Income: 2787.85
# Expenses: 7341.45
# Remaining Balance: 553015.95
# IRA Balance: 416269.05
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 7:
# Income: 2765.08
# Expenses: 7341.45
# Remaining Balance: 548439.58
# IRA Balance: 419044.18
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 8:
# Income: 2742.20
# Expenses: 7341.45
# Remaining Balance: 543840.32
# IRA Balance: 421837.80
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 9:
# Income: 2719.20
# Expenses: 7341.45
# Remaining Balance: 539218.07
# IRA Balance: 424650.06
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 10:
# Income: 2696.09
# Expenses: 7341.45
# Remaining Balance: 534572.71
# IRA Balance: 427481.06
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 11:
# Income: 2672.86
# Expenses: 7341.45
# Remaining Balance: 529904.12
# IRA Balance: 430330.93
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2023, Month 12:
# Income: 2649.52
# Expenses: 7341.45
# Remaining Balance: 525212.19
# IRA Balance: 433199.80
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 1:
# Income: 2626.06
# Expenses: 7693.11
# Remaining Balance: 520145.14
# IRA Balance: 436087.80
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 2:
# Income: 2600.73
# Expenses: 7693.11
# Remaining Balance: 515052.76
# IRA Balance: 438995.05
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 3:
# Income: 2575.26
# Expenses: 7693.11
# Remaining Balance: 509934.92
# IRA Balance: 441921.69
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 4:
# Income: 2549.67
# Expenses: 7693.11
# Remaining Balance: 501109.02
# IRA Balance: 444867.83
# Federal Tax: 3231.53
# CA Tax: 450.94
# Total Tax: 3682.47
#
# Year 2024, Month 5:
# Income: 2505.55
# Expenses: 7693.11
# Remaining Balance: 495921.46
# IRA Balance: 447833.62
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 6:
# Income: 2479.61
# Expenses: 7693.11
# Remaining Balance: 490707.95
# IRA Balance: 450819.17
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 7:
# Income: 2453.54
# Expenses: 7693.11
# Remaining Balance: 485468.39
# IRA Balance: 453824.64
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 8:
# Income: 2427.34
# Expenses: 7693.11
# Remaining Balance: 480202.62
# IRA Balance: 456850.13
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 9:
# Income: 2401.01
# Expenses: 7693.11
# Remaining Balance: 474910.53
# IRA Balance: 459895.80
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 10:
# Income: 2374.55
# Expenses: 7693.11
# Remaining Balance: 469591.97
# IRA Balance: 462961.77
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 11:
# Income: 2347.96
# Expenses: 7693.11
# Remaining Balance: 464246.82
# IRA Balance: 466048.18
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2024, Month 12:
# Income: 2321.23
# Expenses: 7693.11
# Remaining Balance: 458874.95
# IRA Balance: 469155.17
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 1:
# Income: 2294.37
# Expenses: 7924.90
# Remaining Balance: 453244.42
# IRA Balance: 472282.87
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 2:
# Income: 2266.22
# Expenses: 7924.90
# Remaining Balance: 447585.75
# IRA Balance: 475431.43
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 3:
# Income: 2237.93
# Expenses: 7924.90
# Remaining Balance: 441898.77
# IRA Balance: 478600.97
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 4:
# Income: 2209.49
# Expenses: 7924.90
# Remaining Balance: 433080.57
# IRA Balance: 481791.64
# Federal Tax: 2741.67
# CA Tax: 361.13
# Total Tax: 3102.80
#
# Year 2025, Month 5:
# Income: 2165.40
# Expenses: 7924.90
# Remaining Balance: 427321.07
# IRA Balance: 485003.59
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 6:
# Income: 2136.61
# Expenses: 7924.90
# Remaining Balance: 421532.77
# IRA Balance: 488236.94
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 7:
# Income: 2107.66
# Expenses: 7924.90
# Remaining Balance: 415715.54
# IRA Balance: 491491.86
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 8:
# Income: 2078.58
# Expenses: 7924.90
# Remaining Balance: 409869.21
# IRA Balance: 494768.47
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 9:
# Income: 2049.35
# Expenses: 7924.90
# Remaining Balance: 403993.66
# IRA Balance: 498066.93
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 10:
# Income: 2019.97
# Expenses: 7924.90
# Remaining Balance: 398088.72
# IRA Balance: 501387.37
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 11:
# Income: 1990.44
# Expenses: 7924.90
# Remaining Balance: 392154.27
# IRA Balance: 504729.95
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2025, Month 12:
# Income: 1960.77
# Expenses: 7924.90
# Remaining Balance: 386190.14
# IRA Balance: 508094.82
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 1:
# Income: 1930.95
# Expenses: 8097.43
# Remaining Balance: 380023.66
# IRA Balance: 511482.12
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 2:
# Income: 1900.12
# Expenses: 8097.43
# Remaining Balance: 373826.35
# IRA Balance: 514892.00
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 3:
# Income: 1869.13
# Expenses: 8097.43
# Remaining Balance: 367598.06
# IRA Balance: 518324.61
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 4:
# Income: 1837.99
# Expenses: 8097.43
# Remaining Balance: 358868.87
# IRA Balance: 521780.11
# Federal Tax: 2206.71
# CA Tax: 263.05
# Total Tax: 2469.76
#
# Year 2026, Month 5:
# Income: 1794.34
# Expenses: 8097.43
# Remaining Balance: 352565.79
# IRA Balance: 525258.65
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 6:
# Income: 1762.83
# Expenses: 8097.43
# Remaining Balance: 346231.19
# IRA Balance: 528760.37
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 7:
# Income: 1731.16
# Expenses: 8097.43
# Remaining Balance: 339864.92
# IRA Balance: 532285.44
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 8:
# Income: 1699.32
# Expenses: 8097.43
# Remaining Balance: 333466.82
# IRA Balance: 535834.01
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 9:
# Income: 1667.33
# Expenses: 8097.43
# Remaining Balance: 327036.72
# IRA Balance: 539406.23
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 10:
# Income: 1635.18
# Expenses: 8097.43
# Remaining Balance: 320574.48
# IRA Balance: 543002.28
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 11:
# Income: 1602.87
# Expenses: 8097.43
# Remaining Balance: 314079.93
# IRA Balance: 546622.29
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2026, Month 12:
# Income: 1570.40
# Expenses: 8097.43
# Remaining Balance: 307552.90
# IRA Balance: 550266.44
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 1:
# Income: 1537.76
# Expenses: 8263.67
# Remaining Balance: 300827.00
# IRA Balance: 553934.88
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 2:
# Income: 1504.14
# Expenses: 8263.67
# Remaining Balance: 294067.47
# IRA Balance: 557627.78
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 3:
# Income: 1470.34
# Expenses: 8263.67
# Remaining Balance: 287274.14
# IRA Balance: 561345.30
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 4:
# Income: 1436.37
# Expenses: 8263.67
# Remaining Balance: 278533.60
# IRA Balance: 565087.60
# Federal Tax: 1723.64
# CA Tax: 189.60
# Total Tax: 1913.25
#
# Year 2027, Month 5:
# Income: 1392.67
# Expenses: 8263.67
# Remaining Balance: 271662.60
# IRA Balance: 568854.85
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 6:
# Income: 1358.31
# Expenses: 8263.67
# Remaining Balance: 264757.25
# IRA Balance: 572647.22
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 7:
# Income: 1323.79
# Expenses: 8263.67
# Remaining Balance: 257817.37
# IRA Balance: 576464.87
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 8:
# Income: 1289.09
# Expenses: 8263.67
# Remaining Balance: 250842.79
# IRA Balance: 580307.97
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 9:
# Income: 1254.21
# Expenses: 8263.67
# Remaining Balance: 243833.34
# IRA Balance: 584176.69
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 10:
# Income: 1219.17
# Expenses: 8263.67
# Remaining Balance: 236788.84
# IRA Balance: 588071.20
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 11:
# Income: 1183.94
# Expenses: 8263.67
# Remaining Balance: 229709.11
# IRA Balance: 591991.67
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Year 2027, Month 12:
# Income: 1148.55
# Expenses: 8263.67
# Remaining Balance: 222593.99
# IRA Balance: 595938.28
# Federal Tax: 0.00
# CA Tax: 0.00
# Total Tax: 0.00
#
# Projection complete.
# Total Federal Tax Paid in the First 10 Years: 9903.55
# Total CA State Tax Paid in the First 10 Years: 1264.72
